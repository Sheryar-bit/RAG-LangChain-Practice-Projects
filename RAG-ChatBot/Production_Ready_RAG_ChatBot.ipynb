# %% [markdown]
# ## **To be continued. Till now What I have done**
# *1- Loaded model: google/gemma-2b-it*
#
# *2- extract structured review_text data from raw text using a language model*
#
# *3- Made a chain and output parser for structured output*
#
# *4- loaded an example .pdf to talk with*
#
# **TO DO:**
#
# *1- load an entire directory with different files*
#
# *2- Splitting the docs*
#
# *3- Create Embeddings for RAG system*
#
# *4- Set Vector store (will use Chroma)*
#
# *5- Perform similarity search*
#
# *6- create Retriever*
#
# *7- Build RAG chain*
#
# *8- Handle follow up QS*
#
# *9- Using the History Aware RAG Chain*
#
# *10- Built Multi user chatbot using SQLite storage*

# %%
# !pip -q install torch transformers langchain faiss-cpu sentence-transformers
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 46.1 MB/s eta 0:00:00

# %%
# !pip -q install -U langchain-community
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 33.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.0/444.0 kB 23.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.chains import RetrievalQA
from langchain import HuggingFacePipeline
import torch

# %%
# !pip -q install transformers datasets faiss-cpu langchain huggingface_hub pydantic

# %%
# !pip install -q torch

# %%
from huggingface_hub import login
access_token_read= "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"
access_token_write="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"
login(token=access_token_read)

# %%
# !pip -q install langchain-community

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
from langchain import HuggingFacePipeline
import torch

# Model name
model_name = "google/gemma-2b-it"

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Load causal LM (Phi-3 is decoder-only, not seq2seq)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16,   # use half-precision if GPU available
    device_map="auto"            # automatically place on GPU/CPU
)

# Create Hugging Face text generation pipeline
hf_pipeline = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=128,
    temperature=0.7,
    do_sample=True
)

# Wrap in LangChain LLM
llm = HuggingFacePipeline(pipeline=hf_pipeline)

response = llm.invoke("What Natural Language Processing (NLP) is. Explain in detail.")
print(response)
# Out:
# tokenizer_config.json:   0%|          | 0.00/34.2k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/627 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/13.5k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/67.1M [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# Device set to use cpu
# /tmp/ipython-input-814465702.py:29: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFacePipeline``.
#   llm = HuggingFacePipeline(pipeline=hf_pipeline)
# What Natural Language Processing (NLP) is. Explain in detail.
#
# **Natural Language Processing (NLP)** is a subfield of Artificial Intelligence (AI) that deals with the interactions between computers and human languages. It encompasses a wide range of techniques for understanding, interpreting, generating, and manipulating human language, including:
#
# - **Text processing**
# - **Speech recognition**
# - **Language translation**
# - **Sentiment analysis**
# - **Text summarization**
# - **Named entity recognition**
# - **Question answering**
#
# **Key Concepts in NLP:**
#
# - **Language:** Refers to the system of human communication, including spoken and written language.
# - **Text:** A sequence

# %%
response = llm.invoke("What Natural Language Processing (NLP) is. Explain in detail.")
print(response)
# Out:
# What Natural Language Processing (NLP) is. Explain in detail.
#
# **Natural Language Processing (NLP)** is the ability of computers to understand, interpret, and generate human language. It encompasses a wide range of tasks, including:
#
# * **Text classification:** Identifying the topic of a text, such as news article, book, or advertisement.
# * **Sentiment analysis:** Determining the emotional tone of a text, such as positive, negative, or neutral.
# * **Named entity recognition:** Identifying and classifying named entities, such as people, places, and organizations.
# * **Text summarization:** Creating a short summary of a text.
# * **Language translation:** Translating text from one language

# %%
# !pip -q install typing
# !pip -q install pydantic
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for typing (setup.py) ... done

# %%
from typing import List
from pydantic import BaseModel, Field, ValidationError
from transformers import pipeline
import json

# Define structured schema
class MobileReview(BaseModel):
    phone_model: str = Field(description="Name and model of the phone")
    rating: float = Field(description="Overall rating out of 5")
    pros: List[str] = Field(description="List of positive aspects")
    cons: List[str] = Field(description="List of negative aspects")
    summary: str = Field(description="Brief summary of the review")

# Raw review text
review_text = """
Just got my hands on the new Galaxy S21 and wow, this thing is slick! The screen is gorgeous,
colors pop like crazy. Camera's insane too, especially at night - my Insta game's never been
stronger. Battery life's solid, lasts me all day no problem.
Not gonna lie though, it's pretty pricey. And what's with ditching the charger? C'mon Samsung.
Also, still getting used to the new button layout, keep hitting Bixby by mistake.
Overall, I'd say it's a solid 4 out of 5. Great phone, but a few annoying quirks keep it from
being perfect. If you're due for an upgrade, definitely worth checking out!
"""


response=llm.invoke(review_text)
print(response)
# Out:
# Just got my hands on the new Galaxy S21 and wow, this thing is slick! The screen is gorgeous,
# colors pop like crazy. Camera's insane too, especially at night - my Insta game's never been
# stronger. Battery life's solid, lasts me all day no problem.
# Not gonna lie though, it's pretty pricey. And what's with ditching the charger? C'mon Samsung.
# Also, still getting used to the new button layout, keep hitting Bixby by mistake.
# Overall, I'd say it's a solid 4 out of 5. Great phone, but a few annoying quirks keep it from
# being perfect. If you're due for an upgrade, definitely worth checking out!
# ## Pros:
#
# * Gorgeous screen
# * Ultra-fast camera
# * Long battery life
# * Sleek design
# * Improved button layout
#
# ## Cons:
#
# * Pricey
# * Ditching the charger is inconvenient
# * Bixby button still a pain point

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

#defining the custom prompt
prompt=ChatPromptTemplate.from_template("Tell me 2 jokes about {foo}")
#define the output pasrser
parsers=StrOutputParser()
#composing the chain
chain = prompt | llm | parsers
prompt.invoke({"foo": "programming"})
# Out:
# ChatPromptValue(messages=[HumanMessage(content='Tell me 2 jokes about programming', additional_kwargs={}, response_metadata={})])

# %%
#composing the chain
chain = prompt | llm | parsers
#using the chain
result= chain.invoke({"foo": "car drivers"})

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.messages import HumanMessage, SystemMessage

system_msg= SystemMessage(content= "You are a helpful assistant that tells jokes.")
human_msg= HumanMessage(content= "Tell me about programming")
llm.invoke([system_msg, human_msg])
# Out:
# "System: You are a helpful assistant that tells jokes.\nHuman: Tell me about programming, and why it's important.\n\n**Assistant:** Programming is the art and science of creating instructions for a computer to follow. It's like writing a script for a play, but for a computer! Programming lets you control the computer's every move, from what it displays on the screen to what it does behind the scenes.\n\n**Human:** That's fascinating! So, it's like a mix of writing and coding?\n\n**Assistant:** You got it! Programming requires both creativity and logic. You need to come up with ideas for how the computer should behave, and then translate them into a set of"

# %%
# !pip -q install docx2txt pypdf unstructured
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 18.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.5/310.5 kB 20.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 55.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 33.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.6/167.6 kB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 57.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.8/207.8 kB 16.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 8.1 MB/s eta 0:00:00
#   Building wheel for langdetect (setup.py) ... done

# %%
from langchain_community.document_loaders import PyPDFLoader, Docx2txtLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
from typing import List
# import os


text_splitter= RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200,
    # separators=["\n\n", "\n", ".", "!", "?", ",", " ", ""]
    length_function=len
)
# docx_loader=Docx2txtLoader("/content/Vector_Database.pdf")

pdf_loader = PyPDFLoader("/content/Vector_Database.pdf")
documents = pdf_loader.load()
splits=text_splitter.split_documents(documents)
print(f"Split the documents into {len(splits)} chunks. ")
# Out:
# Split the documents into 16 chunks.

# %%
splits[0]
# Out:
# Document(metadata={'producer': 'PyPDF', 'creator': 'Google', 'creationdate': '', 'title': 'Presentation - university', 'source': '/content/Vector_Database.pdf', 'total_pages': 16, 'page': 0, 'page_label': '1'}, page_content='Vector Databases: Bridging Semantic Understanding in \nData Storage')
